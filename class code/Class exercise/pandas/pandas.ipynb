# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("Match.csv")

# %%
df.head()
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08             2                 1          1
# 1    335988  19-Apr-08             4                 3          1
# 2    335989  19-Apr-08             6                 5          1
# 3    335990  20-Apr-08             7                 2          1
# 4    335991  20-Apr-08             1                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# 4                                Eden Gardens               8           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# ...

# %%
df.head(4)
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08             2                 1          1
# 1    335988  19-Apr-08             4                 3          1
# 2    335989  19-Apr-08             6                 5          1
# 3    335990  20-Apr-08             7                 2          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# 0             0          1                  0     by runs   140.0
# 1             0          1                  0     by runs    33.0
# ...

# %%
df.tail()
# Out:
#      Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 572    981016  22-May-16             6                 2          9
# 573    981018  24-May-16            13                 2          9
# 574    981020  25-May-16            11                 1          9
# 575    981022  27-May-16            13                11          9
# 576    981024  29-May-16             2                11          9
#
#                                            Venue_Name  Toss_Winner_Id  \
# 572  Shaheed Veer Narayan Singh International Stadium               2
# 573                             M Chinnaswamy Stadium               2
# 574                                  Feroz Shah Kotla               1
# 575                                  Feroz Shah Kotla              11
# 576                             M Chinnaswamy Stadium              11
#
#     Toss_Decision  IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  \
# ...

# %%
df.head(10)
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08             2                 1          1
# 1    335988  19-Apr-08             4                 3          1
# 2    335989  19-Apr-08             6                 5          1
# 3    335990  20-Apr-08             7                 2          1
# 4    335991  20-Apr-08             1                 8          1
# 5    335992  21-Apr-08             5                 4          1
# 6    335993  22-Apr-08             8                 6          1
# 7    335994  23-Apr-08             3                 7          1
# 8    335995  24-Apr-08             8                 5          1
# 9    335996  25-Apr-08             4                 7          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# ...

# %%
df.tail(7)
# Out:
#      Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 570    981012  21-May-16            13                 7          9
# 571    981014  22-May-16             1                11          9
# 572    981016  22-May-16             6                 2          9
# 573    981018  24-May-16            13                 2          9
# 574    981020  25-May-16            11                 1          9
# 575    981022  27-May-16            13                11          9
# 576    981024  29-May-16             2                11          9
#
#                                            Venue_Name  Toss_Winner_Id  \
# 570                                        Green Park              13
# 571                                      Eden Gardens              11
# 572  Shaheed Veer Narayan Singh International Stadium               2
# 573                             M Chinnaswamy Stadium               2
# 574                                  Feroz Shah Kotla               1
# ...

# %%
pip install seaborn
# Out:
# ...
#      ------------------------------------ 293.3/293.3 kB 341.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sb

# %%
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
sb.catplot(data=df, x="sepal_length", y="sepal_width")

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn[stats]
# Out:
# ...
#
# ...
#      ---------------------------------------- 9.1/9.1 MB 167.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 233.8/233.8 kB 227.2 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categories = ["sepal_length","sepal_width","petal_length","petal_width,species"]
values = [10, 20, 15]

sns.barplot(x=categories, y=values)
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Categorical Data Visualization")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categories = ["Category A", "Category B", "Category C"]
values = [10, 20, 15]

sns.barplot(x=categories, y=values)
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Categorical Data Visualization")
plt.show()

# %% [markdown]
# 1. load a csv,set new col names
# 2. rename column name(1.column,multiple column)
# 3. load  a dataset , set one column as index column
# 4. split your data into multiple files wrt rows and columns -- (merge & join)in excel
# 5. load the default files amd merge them to final file

# %%
import pandas as pd

# %%
import pandas as pd

# Load CSV file
data = pd.read_csv('Iris.csv')

# Set new column names
new_column_names = ['seplen', 'sepwid', 'petlen','petwid','spe']
data.columns = new_column_names

# %%
print(data)
# Out:
#      seplen  sepwid  petlen  petwid             spe
# 0       5.1     3.5     1.4     0.2     Iris-setosa
# 1       4.9     3.0     1.4     0.2     Iris-setosa
# 2       4.7     3.2     1.3     0.2     Iris-setosa
# 3       4.6     3.1     1.5     0.2     Iris-setosa
# 4       5.0     3.6     1.4     0.2     Iris-setosa
# ..      ...     ...     ...     ...             ...
# 145     6.7     3.0     5.2     2.3  Iris-virginica
# 146     6.3     2.5     5.0     1.9  Iris-virginica
# 147     6.5     3.0     5.2     2.0  Iris-virginica
# 148     6.2     3.4     5.4     2.3  Iris-virginica
# 149     5.9     3.0     5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.rename(columns={'sepwid': 'sepw'}, inplace=True)
print(data)
# Out:
#      sepl  sepw  petlen  petwid             spe
# 0     5.1   3.5     1.4     0.2     Iris-setosa
# 1     4.9   3.0     1.4     0.2     Iris-setosa
# 2     4.7   3.2     1.3     0.2     Iris-setosa
# 3     4.6   3.1     1.5     0.2     Iris-setosa
# 4     5.0   3.6     1.4     0.2     Iris-setosa
# ..    ...   ...     ...     ...             ...
# 145   6.7   3.0     5.2     2.3  Iris-virginica
# 146   6.3   2.5     5.0     1.9  Iris-virginica
# 147   6.5   3.0     5.2     2.0  Iris-virginica
# 148   6.2   3.4     5.4     2.3  Iris-virginica
# 149   5.9   3.0     5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# q.Write a python with the following specification
# Func Name Create dataset
# Which will take dict ,filename, no of rows as arguments
# The dict is having the following structure
# {
#     "Columnname" : [domain of value]
# }
# Your function will select random valued for each of the domain and
# create a row for you the no of rows that has to be created is as parameter
#  save the file with the required number of rows load this dataset using pandas
#  and display basic information .which include head tail no of rows

# %%
import pandas as pd
import random

def createdataset(dictionary,filename,num_of_rows) :
    pass

dict = {
    "age":[23,24,25,26],
    "DOB": ["Sep","May","June","Aug"],
    "Place": ["Hyd","Pune","Delhi","Agra"],
    "UID": ["23101","23102","2312201","2312204"],
    "Gender": ["female","male"],
}
  
createdataset(dict,"mydata.csv",200)
random2 = random.shuffle(["Sep","May","June","Aug"] )    

random_s = dict["age"][random.randint(0,3)]

print(random_s)
# Out:
# 26
